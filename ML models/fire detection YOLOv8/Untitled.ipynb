# %%
from ultralytics import YOLO

# %%
model = YOLO()

# %%
model.train(data=r'F:\ai\AI-Development\Yolo v8\5. fire detection YOLOv8\fire\data.yaml', epochs=100, augment=False)
# Out:
# Ultralytics 8.3.91  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model = r"F:\camera\fire detection YOLOv8\fire\runs\detect\train9\weights\best.pt"

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# %%
model = YOLO(model)

# %%
file_path = r"F:\camera\fire detection YOLOv8\fire\fire.jpg"


results = model.predict(source=file_path,conf=.5, save=False)

for r in results:
    img = r.plot()  # Get annotated image as numpy array
    img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    img.show()
# Out:
# image 1/1 F:\camera\fire detection YOLOv8\fire\fire.jpg: 448x640 1 fire, 108.0ms
# Speed: 4.4ms preprocess, 108.0ms inference, 123.9ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# ## using web came

# %%
from ultralytics import YOLO
# Out:
# WARNING Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\write\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
file = r"runs\detect\train9\weights\best.pt"
model = YOLO(file)

# %%
import cv2

video_path = "video.mp4"
# cap = cv2.VideoCapture(video_path)
cap = cv2.VideoCapture(0)

frame_width = 640
frame_height = 480

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (frame_width, frame_height))

    results = model.predict(source=frame, conf=0.23, save=False)

    for r in results:
        annotated_frame = r.plot()

        cv2.imshow("YOLOv8 Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 other, 97.3ms
# Speed: 10.5ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 others, 131.3ms
# Speed: 2.4ms preprocess, 131.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 other, 157.9ms
# Speed: 3.4ms preprocess, 157.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 others, 110.3ms
# Speed: 1.3ms preprocess, 110.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 others, 90.7ms
# Speed: 1.2ms preprocess, 90.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 other, 92.8ms
# Speed: 1.2ms preprocess, 92.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 other, 92.5ms
# Speed: 2.7ms preprocess, 92.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 other, 77.3ms
# ...

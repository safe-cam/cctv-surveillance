# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data="F:\camera\license plate rec\dataset\data.yaml", epochs=10, batch=16, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.96 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.94  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# # Phase II (*10 - 20 Epochs*)

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"F:\camera\license plate rec\runs\detect\train\weights\best.pt")

# %%
model.train(data=r'F:\camera\license plate rec\dataset\data.yaml', epochs=10, batch=16, imgsz=640)
# Out:
# Ultralytics 8.3.94  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# # Phase III (*20 - 30 Epochs*)

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"F:\camera\license plate rec\runs\detect\train2\weights\best.pt")

# %%
model.train(data=r'F:\camera\license plate rec\dataset\data.yaml', epochs=10, batch=16, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.97 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.94  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# ## Phase IV (*30 - 40 Epochs*)

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"F:\camera\license plate rec\runs\detect\train3\weights\best.pt")

# %%
model.train(data=r'F:\camera\license plate rec\dataset\data.yaml', epochs=10, batch=16, imgsz=640)
# Out:
# Ultralytics 8.3.94  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# # Phase V (*40 - 50 Epochs*)

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"F:\camera\license plate rec\runs\detect\train4\weights\best.pt")

# %%
model.train(data=r'F:\camera\license plate rec\dataset\data.yaml', epochs=10, batch=16, imgsz=640)
# Out:
# Ultralytics 8.3.94  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# # Testing

# %%
from ultralytics import YOLO

# %%
import cv2
import easyocr
import numpy as np
from ultralytics import YOLO

video_path = r"F:\camera\license plate rec\demo.mp4"
model_path = r"F:\camera\license plate rec\runs\detect\train5\weights\best.pt"

model = YOLO(model_path)

cap = cv2.VideoCapture(video_path)

target_width = 800
target_height = 600

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (target_width, target_height))

    results = model(frame)

    for result in results:
        for box in result.boxes.data:
            x1, y1, x2, y2, conf, cls = map(int, box)

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

    cv2.imshow("License Plate Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 License_Plate, 68.8ms
# Speed: 8.6ms preprocess, 68.8ms inference, 256.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 License_Plates, 8.3ms
# Speed: 3.5ms preprocess, 8.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 License_Plates, 7.3ms
# Speed: 3.7ms preprocess, 7.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 License_Plate, 16.4ms
# Speed: 5.2ms preprocess, 16.4ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 License_Plates, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 License_Plates, 11.3ms
# ...

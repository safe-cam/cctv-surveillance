# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt') # load a pretrained model

# %% [markdown]
# #### hyper parameter using following parameters
# <pre>
# model.train(
#     data='data.yaml',
#     epochs=150,
#     batch=16,
#     imgsz=640,
#     lr0=0.001,
#     lrf=0.01,
#     momentum=0.9,
#     weight_decay=0.0005,
#     optimizer='AdamW',
#     patience=25,
#     warmup_epochs=3,
#     scale=0.5,
#     hsv_h=0.02,
#     hsv_s=0.7,
#     hsv_v=0.4,
#     fliplr=0.5,
#     flipud=0.3
# )
# </pre>

# %%
model.train(data='data.yaml', epochs=100)  # train the model

# %% [markdown]
# # Testing

# %% [markdown]
# ## Loading Model

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"F:\camera\Vehicle detection YOLOv8\runs\detect\train3\weights\best.pt")

# %%
model.names
# Out:
# {0: 'Car', 1: 'Motorcycle', 2: 'Truck', 3: 'Bus', 4: 'Bicycle'}

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# %%
model.names
# Out:
# {0: 'Car', 1: 'Motorcycle', 2: 'Truck', 3: 'Bus', 4: 'Bicycle'}

# %% [markdown]
# # Testing

# %%
import cv2
import torch


vehicle_classes = {0: 'Car', 1: 'Motorcycle', 2: 'Truck', 3: 'Bus', 4: 'Bicycle'}

class Rectangle:
    def __init__(self, x, y, w, h, label):
        self.x = int(x)
        self.y = int(y)
        self.w = int(w)
        self.h = int(h)
        self.label = label

    def draw(self, frame):
        cv2.rectangle(frame, (self.x, self.y), (self.x + self.w, self.y + self.h), (0, 255, 0), 2)
        cv2.putText(frame, self.label, (self.x, self.y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

def detect_vehicles(video_path, resize_width=800):
    cap = cv2.VideoCapture(video_path)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        height, width = frame.shape[:2]
        aspect_ratio = height / width
        new_height = int(resize_width * aspect_ratio)
        frame = cv2.resize(frame, (resize_width, new_height))

        results = model(frame)

        for result in results:
            for box in result.boxes.data:
                x1, y1, x2, y2, conf, cls = box.tolist()
                cls = int(cls)
                if conf >= 0.7 and cls in vehicle_classes:  # <- Add confidence check here
                    label = f"{vehicle_classes[cls]} ({conf:.2f})"
                    rect = Rectangle(x1, y1, x2 - x1, y2 - y1, label)
                    rect.draw(frame)

        cv2.imshow("Vehicle Detection", frame)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# video_path = "demo.mp4"
video_path = r"C:\Users\write\Downloads\Itni khushi _ 🥹😭 _ Hoor72.com_template_itni-khushi-meme.mp4"
detect_vehicles(video_path)
# Out:
# 0: 640x640 2 Cars, 1 Motorcycle, 25.6ms
# Speed: 236.5ms preprocess, 25.6ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 8.7ms
# Speed: 4.9ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 10.3ms
# Speed: 5.1ms preprocess, 10.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.8ms
# Speed: 5.8ms preprocess, 9.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.9ms
# Speed: 5.5ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Motorcycle, 8.8ms
# Speed: 3.7ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Motorcycle, 9.2ms
# Speed: 5.6ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Motorcycles, 8.6ms
# Speed: 3.6ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.8ms
# Speed: 5.2ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.4ms
# Speed: 4.3ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.5ms
# Speed: 5.0ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.8ms
# Speed: 6.9ms preprocess, 12.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 16.3ms
# Speed: 4.6ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 11.1ms
# Speed: 5.3ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.4ms
# Speed: 6.6ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.6ms
# Speed: 6.9ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.0ms
# Speed: 4.2ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.6ms
# Speed: 4.0ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.7ms
# Speed: 7.6ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.8ms
# Speed: 6.3ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 11.7ms
# Speed: 8.1ms preprocess, 11.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 9.6ms
# Speed: 6.3ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.8ms
# Speed: 5.5ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 10.4ms
# Speed: 6.9ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 15.1ms
# Speed: 5.9ms preprocess, 15.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.8ms
# Speed: 7.8ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.8ms
# Speed: 3.9ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.7ms
# Speed: 3.9ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.8ms
# Speed: 4.2ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.7ms
# Speed: 4.6ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.3ms
# Speed: 6.2ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 12.6ms
# Speed: 5.9ms preprocess, 12.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 16.9ms
# Speed: 9.0ms preprocess, 16.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.0ms
# Speed: 8.1ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 14.5ms
# Speed: 7.8ms preprocess, 14.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 14.8ms
# Speed: 8.2ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.2ms
# Speed: 7.5ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.4ms
# Speed: 8.6ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.1ms
# Speed: 5.8ms preprocess, 13.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.4ms
# Speed: 5.6ms preprocess, 13.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 17.5ms
# Speed: 7.5ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.1ms
# Speed: 5.1ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.7ms
# Speed: 8.5ms preprocess, 13.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.5ms
# Speed: 7.2ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.9ms
# Speed: 4.2ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 13.9ms
# Speed: 5.6ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 14.3ms
# Speed: 7.0ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 17.0ms
# Speed: 7.1ms preprocess, 17.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 14.6ms
# Speed: 7.8ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 14.7ms
# Speed: 6.1ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 14.8ms
# Speed: 8.4ms preprocess, 14.8ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 14.7ms
# Speed: 7.6ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 14.8ms
# Speed: 4.7ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 14.8ms
# Speed: 4.8ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 14.8ms
# Speed: 4.4ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 15.3ms
# Speed: 9.0ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.4ms
# Speed: 6.1ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.4ms
# Speed: 6.5ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 15.3ms
# Speed: 4.5ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.5ms
# Speed: 5.3ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.6ms
# Speed: 7.8ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.7ms
# Speed: 4.0ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.9ms
# Speed: 5.0ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 15.8ms
# Speed: 4.2ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 16.1ms
# Speed: 7.6ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 16.5ms
# Speed: 7.6ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 16.2ms
# Speed: 8.1ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 16.2ms
# Speed: 6.7ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 16.7ms
# Speed: 6.1ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 16.7ms
# Speed: 5.1ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 16.6ms
# Speed: 5.1ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 17.4ms
# Speed: 8.6ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 17.2ms
# Speed: 4.5ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 17.3ms
# Speed: 7.4ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 17.4ms
# Speed: 6.9ms preprocess, 17.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 17.4ms
# Speed: 8.1ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 17.5ms
# Speed: 7.7ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 17.7ms
# Speed: 6.6ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 17.7ms
# Speed: 5.5ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Cars, 17.8ms
# Speed: 4.2ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 1 Bicycle, 18.3ms
# Speed: 4.2ms preprocess, 18.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bicycle, 18.4ms
# Speed: 5.1ms preprocess, 18.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bicycle, 18.4ms
# Speed: 8.8ms preprocess, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bicycle, 18.6ms
# Speed: 9.1ms preprocess, 18.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Cars, 1 Motorcycle, 1 Bicycle, 18.6ms
# Speed: 7.5ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bicycle, 19.5ms
# Speed: 6.8ms preprocess, 19.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 19.2ms
# Speed: 7.9ms preprocess, 19.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 19.0ms
# Speed: 7.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.4ms
# Speed: 8.7ms preprocess, 20.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 19.2ms
# Speed: 8.3ms preprocess, 19.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 19.3ms
# Speed: 6.5ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 19.7ms
# Speed: 5.8ms preprocess, 19.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.0ms
# Speed: 5.7ms preprocess, 20.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.1ms
# Speed: 7.2ms preprocess, 20.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.6ms
# Speed: 7.1ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.5ms
# Speed: 6.7ms preprocess, 20.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 20.5ms
# Speed: 4.8ms preprocess, 20.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 20.5ms
# Speed: 4.3ms preprocess, 20.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 2 Buss, 20.6ms
# Speed: 6.1ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 20.4ms
# Speed: 5.4ms preprocess, 20.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 2 Buss, 21.1ms
# Speed: 6.2ms preprocess, 21.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 20.7ms
# Speed: 4.7ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 20.7ms
# Speed: 5.9ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bus, 21.6ms
# Speed: 7.0ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bus, 21.4ms
# Speed: 6.8ms preprocess, 21.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bus, 21.4ms
# Speed: 7.5ms preprocess, 21.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Bus, 21.5ms
# Speed: 4.5ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 1 Bus, 21.4ms
# Speed: 5.1ms preprocess, 21.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 1 Bus, 22.6ms
# Speed: 9.8ms preprocess, 22.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 1 Bus, 22.7ms
# Speed: 8.2ms preprocess, 22.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 22.5ms
# Speed: 9.4ms preprocess, 22.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 22.4ms
# Speed: 7.7ms preprocess, 22.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 1 Motorcycle, 22.3ms
# Speed: 4.4ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Cars, 1 Motorcycle, 22.4ms
# Speed: 4.3ms preprocess, 22.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bicycle, 22.4ms
# Speed: 6.1ms preprocess, 22.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 25.1ms
# Speed: 4.2ms preprocess, 25.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 23.6ms
# Speed: 9.1ms preprocess, 23.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 23.6ms
# Speed: 8.8ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 23.5ms
# Speed: 7.8ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 23.6ms
# Speed: 7.8ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 23.6ms
# Speed: 7.9ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 23.8ms
# Speed: 6.4ms preprocess, 23.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 23.9ms
# Speed: 8.9ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 23.9ms
# Speed: 7.6ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 24.0ms
# Speed: 9.0ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 23.8ms
# Speed: 7.0ms preprocess, 23.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 24.0ms
# Speed: 8.0ms preprocess, 24.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 25.3ms
# Speed: 5.4ms preprocess, 25.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 24.8ms
# Speed: 4.6ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 24.8ms
# Speed: 4.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 24.8ms
# Speed: 5.1ms preprocess, 24.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 24.8ms
# Speed: 4.3ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 2 Buss, 25.1ms
# Speed: 4.7ms preprocess, 25.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 25.1ms
# Speed: 5.0ms preprocess, 25.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 2 Buss, 25.2ms
# Speed: 4.5ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 25.3ms
# Speed: 4.3ms preprocess, 25.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 25.3ms
# Speed: 4.7ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 25.3ms
# Speed: 5.5ms preprocess, 25.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 25.1ms
# Speed: 8.7ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bus, 25.2ms
# Speed: 7.9ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 25.2ms
# Speed: 4.9ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 25.8ms
# Speed: 7.7ms preprocess, 25.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 1 Bus, 26.3ms
# Speed: 4.4ms preprocess, 26.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.2ms
# Speed: 4.2ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.3ms
# Speed: 6.0ms preprocess, 26.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.3ms
# Speed: 4.7ms preprocess, 26.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.4ms
# Speed: 7.4ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.7ms
# Speed: 6.8ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.9ms
# Speed: 9.1ms preprocess, 26.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.7ms
# Speed: 6.8ms preprocess, 26.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.7ms
# Speed: 6.5ms preprocess, 26.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.7ms
# Speed: 8.5ms preprocess, 26.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 27.4ms
# Speed: 7.7ms preprocess, 27.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.8ms
# Speed: 6.9ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.8ms
# Speed: 6.9ms preprocess, 26.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.7ms
# Speed: 8.0ms preprocess, 26.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.6ms
# Speed: 4.9ms preprocess, 26.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 5.1ms preprocess, 25.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 5.7ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 8.2ms preprocess, 25.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 8.2ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.3ms
# Speed: 6.7ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Motorcycle, 25.3ms
# Speed: 6.1ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 5.5ms preprocess, 25.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 5.9ms preprocess, 25.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 7.0ms preprocess, 25.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 6.4ms preprocess, 25.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 8.2ms preprocess, 25.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 5.9ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 5.7ms preprocess, 25.2ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 6.9ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 4.3ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 4.5ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 8.5ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 6.1ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.3ms
# Speed: 7.1ms preprocess, 25.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.5ms
# Speed: 7.4ms preprocess, 25.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 7.6ms preprocess, 25.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 25.2ms
# Speed: 6.7ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 26.4ms
# Speed: 6.9ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 26.4ms
# Speed: 7.8ms preprocess, 26.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 26.4ms
# Speed: 9.8ms preprocess, 26.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 25.1ms
# Speed: 4.8ms preprocess, 25.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 7.4ms preprocess, 25.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.3ms
# Speed: 5.9ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 4.9ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.1ms
# Speed: 4.4ms preprocess, 25.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 5.2ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 6.1ms preprocess, 25.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.3ms
# Speed: 9.4ms preprocess, 25.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 4.9ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.3ms
# Speed: 8.2ms preprocess, 25.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.3ms
# Speed: 7.3ms preprocess, 25.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 6.5ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 5.9ms preprocess, 25.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.3ms
# Speed: 4.7ms preprocess, 25.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 5.7ms preprocess, 25.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bicycle, 25.2ms
# Speed: 6.5ms preprocess, 25.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bicycle, 25.2ms
# Speed: 7.6ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Bicycle, 25.2ms
# Speed: 8.0ms preprocess, 25.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 25.1ms
# Speed: 6.1ms preprocess, 25.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Motorcycle, 25.2ms
# Speed: 4.3ms preprocess, 25.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bicycle, 25.2ms
# Speed: 4.8ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 5.6ms preprocess, 25.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 8.1ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 25.2ms
# Speed: 4.8ms preprocess, 25.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.3ms
# Speed: 7.5ms preprocess, 25.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.3ms
# Speed: 7.3ms preprocess, 26.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.3ms
# Speed: 5.7ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.4ms
# Speed: 7.6ms preprocess, 26.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.9ms
# Speed: 9.1ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.4ms
# Speed: 8.0ms preprocess, 26.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.3ms
# Speed: 7.7ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.2ms
# Speed: 4.7ms preprocess, 26.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.5ms
# Speed: 7.2ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.3ms
# Speed: 7.4ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.2ms
# Speed: 4.5ms preprocess, 26.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.8ms
# Speed: 7.4ms preprocess, 26.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.4ms
# Speed: 8.3ms preprocess, 26.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.3ms
# Speed: 5.7ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.3ms
# Speed: 5.1ms preprocess, 26.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Cars, 26.3ms
# Speed: 7.9ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 1 Bus, 26.5ms
# Speed: 9.1ms preprocess, 26.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 26.4ms
# Speed: 7.0ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.3ms
# Speed: 6.2ms preprocess, 26.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Car, 26.3ms
# Speed: 6.4ms preprocess, 26.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 27.0ms
# Speed: 6.7ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 7.5ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 6.7ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 4.7ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 4.3ms preprocess, 25.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.2ms
# Speed: 6.3ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 25.1ms
# Speed: 4.6ms preprocess, 25.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
